# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title :  Case Study - Webscrapping on Trip Advisor
#
# #### Name: Chong Mun Chen
#
# #### IC Number: 960327-07-5097
#
# #### Date : 4/7/2023
#
# #### Introduction : Practising more with BeautifulSoup and Selenium on this Trip Advisor exercise.
#
#
#
# #### Conclusion : I know more about the extensions and limitations of using the methods available in the BeautifulSoup and Selenium packages.

# %% [markdown]
# Instruction: Use Selenium and Beautiful Soup to extract the first 5 comments and their titles from the trip advisor link.
#
# Url: https://www.tripadvisor.com/Airline_Review-d8729220-Reviews-AirAsia-AirAsia-Berhad-Malaysia

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from bs4 import BeautifulSoup

# driver = webdriver.Chrome('C:\\Users\ACER\Desktop\ChromeDriver\chromedriver')
driver = webdriver.Chrome()

# %%
import time

driver.get("https://www.tripadvisor.com/Airline_Review-d8729220-Reviews-AirAsia-AirAsia-Berhad-Malaysia")
time.sleep(5)

comments = []
for page in range(1, 6):
    soup = BeautifulSoup(driver.page_source,'html.parser')
    soup_list = soup.find_all("div", attrs={"class":"WAllg _T"})
        
    header = ''
    body = ''
    for items in range(len(soup_list)):
        header = soup_list[items].find("a", attrs={"class":"Qwuub"}).text     
        body = soup_list[items].find('div', attrs={'class':'vTVDc'}).find('span', attrs={'class':'QewHA H4 _a'}).text
                
        if body.endswith("…"):
            body = body[:-1]

        comment = f"{header}:\n\t{body}"
        comments.append(comment)
            
    if page == 1:
        driver.find_element(By.XPATH, '//*[@id="component_1"]/div/div[5]/div/div/div/div[2]/div[1]/div[2]/div/div[8]/div/a').click()
        time.sleep(5)
    elif page == 5:
        break
    else:
        driver.find_element(By.XPATH, '//*[@id="component_1"]/div/div[5]/div/div/div/div[2]/div[1]/div[2]/div/div[8]/div/a[2]').click()
        time.sleep(5)
        
driver.quit()

for i, comment in enumerate(comments):
    print(f"Comment {i+1}\n{comment}")
    print()
# Out:
# Comment 1
# Refund declined:
# 	My flight was supposed to be mid of May for a week going to Cebu from Manila but my vacation was cancelled. So May 10 I requested my refund due fir my vacatiin was cancelled. But it took 2 mobths vefire they respond to me and suddenly send me this email attached abd declined my 15000 refund.
#
# Comment 2
# The worth Airline you can fly with:
# 	I traveled through Asia during 22 days and flew with 8 different Airlines companies. I did not have any problem with my luggage with 7 Airlines (Qatar x2, Lion Air x2, Sriwijaya Air (Nam Air), Batik Air Malaysia, Bangkok Airways x2, Cambodia Angkor Air, Smile (Thai Airways) Swiss x2). It has been totally different with AirAsia, it is the only company that asked me to pay a fee!! While the price for 2 tickets was  46.66 CHF (=53 USD) with checked luggage included up to 2x20 Kg (40 Kg). I had to pay additional 83.73 CHF (=96 USD, almost twice the price of the ticket) for 1 bag of 23 Kg + 1 bag of 12 Kg + 1 bag of 10 Kg, equivalent to an excess of 5 Kg. 83.73 NCHF for 5 Kg of luggage, I just call that way of acting like stealing!!! It is a bit like with EasyJet in Europe, they attract customer with very low price, but then you have to pay a lot for everything they oblige you to pay! This company must definitely be avoided if you want to have a nice trip without excessive and unacceptable additional high fees to pay.
#
# Comment 3
# WORST EXPERIENCE WITH AIRASIA SUPER APP AND “BO” CHATBOT:
# 	Worst customer service. The chat with Bo is a totally useless app and airasia even has the audacity to direct customer support to this virtual chatbot. Yes a lot of companies are having virtual chatbot now. But airasia is by far the WORST.  1) The chatbot doesn’t even seem to have intelligent AI built into it. Feels like a complete robot replying template answers to customer.  2) Answers and replies in a way that INFURIATES customers instead of helping.  3) customer Receives ZERO help from the chatbot. 4) Makes customer even more angry after using it.  5) no real life customer service support option available.   if any company wants to invent a chatbot that could pissed off all their customers, then AIRASIA are no doubt the champion.   On a side note, airasia announced the change of plane (larger premium flexbed plane to a smaller plane with no flexbed) less than 24hrs before my family is flying. They sent the email around 1am, After the announcement, no calls were made to the customers and basically acts like nothing has happened. We booked the flight because of the premium flexbed option. Was shocked that they can suddenly change the customer preference in such a short notice. The submitting and processing of refund is a NIGHTMARE on the airasia app.  App is either not responding, poor interface, or brings you to some unintended page or not updated with the information entered..   honestly don’t know what is wrong with airasia’s “super” app and chatbot so subpar and low quality. Should let everyone knows how the quality of the airline.
#
# Comment 4
# Delay, delay, delay…never fly Air Asia again:
# 	Never again I will fly Air Asia. Our flight was rescheduled multiple time without announcement and explanation. Obviously no words of apology. Approximately six hours was wasted thanks to poor Air Asia operation. Seriously wonder how such an irresponsible company manage to operate.
#
# Comment 5
# Terrible services!!!:
# 	Terrible chat customer service, didn't provide any solution to my queries. The agent just disconnected without giving proper answer to my questions
#
# Comment 6
# Mr Crawford:
# 	I've flown with this air line once before as I have avoided them like the plague since my last flight. Anyhow I had a credit with my trip ( unfortunately). Air Asia charged me $310 to carry 14.5 kg of gold clubs to the Gold Coast.  They slugged me an extra $139 at the air port
#
# Comment 7
# Still no refund for cancelled flights:
# 	We booked our flight from Auckland To Sydney last December 2022 and due to airline issue they cancelled and postponed our flights multiple times so we had to fly with Air New Zealand. I applied for refund and as of today (July/2023) still I have not got my refund back for all 4
#
# Comment 8
# Triple charged and no refund!!!:
# 	I was triple extra charged for one booking and they don`t have any customer support available only Bo robot which is no use. I tried to proceed with refund 30 times and nothing works. This is a thievery!!
#
# Comment 9
# No refund from Aiaasia for flight cancellation more than 8 months:
# 	I booked Airaisa with booking no. T1ZDJV  but cancelled without any reason or explanation,  so I request to refund on 22/10/22, but 8 months passed till now still no refund, it kept saying being processed,  just wondering is it just automatically replied or really being
#
# Comment 10
# Not good:
# 	There is No food to speak of only the basics which you have to purchase as an extra. There is No alcoholic drinks. The seats are very narrow and I only have a 32 inch waste. Our connecting Flight  from Phuket to Kuala Lumpa was changed from 7.20pm evening to 8.10 in the morning
#
# Comment 11
# Don’t use this airline:
# 	All their flights are delayed we have been waiting over 2 hours I haven’t even gotten in the flight and really not happy. They won’t compensate you for delayed flights.
#
# Comment 12
# The staffs are very very rude:
# 	Regretted  send my son n nephew tru Airasia flight AK0047.. their crew n staff are not friendly or polite..they very very arrogant n rude.. u can see the vd clip n screen shot frm vd clipi shared..how the staff behavior n treat the passenger. Je just chuck the hand carry
#
# Comment 13
# No in-flight entertainment:
# 	I am very bored because there is no in-flight entertainment and im going there for 7 hours! All i do is talk with my cousins and brother, it was so boring
#
# Comment 14
# Nicole and dime airline company :
# 	Bottom of the barrel airline that really runs like the lowest available option. The automatic booking system finds you seats as far as possible from each other, then the airport staff does not accomodate a move together. This is a nickle and dime practice that other budget
#
# Comment 15
# mr:
# 	i had credit account with airasia about $700.00 they clean it up every time i wanted to check my account money all but gone the close the entry the doing maittenice they going from bad to worset
#
# Comment 16
# Great experience, plane needs some refurbishing though. :
# 	The amount of bad reviews here is crazy, and I myself was skeptical before booking due to the reviews. I booked an impromptu flight from Singapore to Penang in June, and the price was okay without baggage or food, but was pricier due to the holidays.  I sat upfront at row 3 in
#
# Comment 17
# One of the worst customer service:
# 	AirAisa rescheduled our flight scheduled to depart from Kota Bharu to KL and from KL to Kuching, this 21st June 2023 resulting in overlapping flight. Despite their assurance on their email that we could change/refund our flight, the process was very difficult. We have to use
#
# Comment 18
# Terrible Booking Process and Waste of Time:
# 	In this era of online services, AirAsia is bumbling backwards further into the stone ages.  Never mind that searching and choosing options online involve such lags, and any edits result in loss of info, the payment system is horrible and kept declining different cards and
#
# Comment 19
# AirAsia is a FRAUD:
# 	I bought an umbrella for RM35 during my flight (AK642) from KUL to DAD with my credit card. Later I found out that AsiaAsia made duplicate charges to my credit card -- a total of 6 times!  I tried to call AsiaAsia but could not get through to them -- all the numbers are no
#
# Comment 20
# Air Asia (& Hutchgo Wholeseller)  is Organised Crime, Taking Advantage of Medical Emergency:
# 	My daughter fell and was rushed by ambulance to St. Luke Manila ER the day prior to our trip to Boracay from Manila. Despite their written policy for a Medical No Fit to Fly and IDs confirming family relationship, both Hutchgo (wholeseller) and Air Asia (service provider)
#
# Comment 21
# Horrendous app navigation that leads to 0 checked in baggage:
# 	Before confirmation, 20kg checked in baggage was available as complimentary. However after booking, NO checked in baggage was available and only 7kg cabin baggage was given. Chat with Elyssa and she informed "it was a mistake on their side"!   Asked for a refund and was informed
#
# Comment 22
# They dont refund and their app or website keep breakdown, cant even book flight under airasia.:
# 	Horrible customer service and interface, totally not user friendly and scammer, refused to refund in cash, credit is not usable.
#
# Comment 23
# Booking nightmare:
# 	I made a booking then realised the date was wrong when I received the itinerary. I know I entered the correct date. The web site is awful and very user unfriendly. Settings like dates and one-way/return are sometimes lost when you go back to change some details like number of
#
# Comment 24
# Damaged luggage, dirty broken chair, broken armrest, unhelpful ground and air staff:
# 	Air Asia caused a major damage on my luggage. We filled a complaint form in the airport and the ground staff accepted the fact that my luggage had a major damage since it cannot be closed anymore. The ground staff was singing while he checked the suitcase, did not offer any
#
# Comment 25
# They wont refund:
# 	The worst airline management i ever ecountered. I dnt onow what happened to ky rerund.. they are scammers.. no emaol response.. customer chat is useless.. in short.. terrible airline management

# %% [markdown]
# Reference: https://medium.com/ymedialabs-innovation/web-scraping-using-beautiful-soup-and-selenium-for-dynamic-page-2f8ad15efe25
